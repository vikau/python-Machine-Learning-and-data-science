# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\ufo.csv",parse_dates=["Time"])

# %%
df
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time
# 0 1930-06-01 22:00:00
# 1 1930-06-30 20:00:00
# 2 1931-02-15 14:00:00
# 3 1931-06-01 13:00:00
# 4 1933-04-18 19:00:00

# %%
df.dtypes
# Out:
# City                       object
# Colors Reported            object
# Shape Reported             object
# State                      object
# Time               datetime64[ns]
# dtype: object

# %%
df.Time[0]
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
df['Time']=pd.to_datetime(df.Time)

# %%
df.Time[0]
# Out:
# Timestamp('1930-06-01 22:00:00')

# %%
df['Time']
# Out:
# 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
# 5       1934-09-15 15:30:00
# 6       1935-06-15 00:00:00
# 7       1936-07-15 00:00:00
# 8       1936-10-15 17:00:00
# 9       1937-06-15 00:00:00
# 10      1937-08-15 21:00:00
# 11      1939-06-01 20:00:00
# 12      1939-06-30 20:00:00
# 13      1939-07-07 02:00:00
# 14      1941-06-01 13:00:00
# 15      1941-07-02 11:30:00
# 16      1942-02-25 00:00:00
# 17      1942-06-01 22:30:00
# 18      1942-07-15 01:00:00
# 19      1943-04-30 23:00:00
# 20      1943-06-01 15:00:00
# 21      1943-08-15 00:00:00
# 22      1943-08-15 00:00:00
# 23      1943-10-15 11:00:00
# 24      1944-01-01 10:00:00
# 25      1944-01-01 12:00:00
# 26      1944-01-01 12:00:00
# 27      1944-04-02 11:00:00
# 28      1944-06-01 12:00:00
# 29      1944-06-30 10:00:00
#                 ...
# 18211   2000-12-28 18:00:00
# 18212   2000-12-28 18:20:00
# ...

# %%
df.Time.dt.weekday_name.value_counts()
# Out:
# Tuesday      2822
# Sunday       2689
# Saturday     2687
# Friday       2669
# Thursday     2598
# Wednesday    2476
# Monday       2300
# Name: Time, dtype: int64

# %%
df.Time.dt.weekday_name
# Out:
# 0           Sunday
# 1           Monday
# 2           Sunday
# 3           Monday
# 4          Tuesday
# 5         Saturday
# 6         Saturday
# 7        Wednesday
# 8         Thursday
# 9          Tuesday
# 10          Sunday
# 11        Thursday
# 12          Friday
# 13          Friday
# 14          Sunday
# 15       Wednesday
# 16       Wednesday
# 17          Monday
# 18       Wednesday
# 19          Friday
# 20         Tuesday
# 21          Sunday
# 22          Sunday
# 23          Friday
# 24        Saturday
# 25        Saturday
# 26        Saturday
# 27          Sunday
# 28        Thursday
# 29          Friday
#            ...
# 18211     Thursday
# 18212     Thursday
# 18213     Thursday
# 18214       Friday
# 18215       Friday
# 18216       Friday
# 18217       Friday
# 18218       Friday
# 18219       Friday
# 18220       Friday
# 18221       Friday
# 18222       Friday
# 18223       Friday
# 18224       Friday
# 18225     Saturday
# 18226     Saturday
# ...

# %%
df['week_day']=df.Time.dt.weekday_name

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State  \
# 0                Ithaca             NaN       TRIANGLE    NY
# 1           Willingboro             NaN          OTHER    NJ
# 2               Holyoke             NaN           OVAL    CO
# 3               Abilene             NaN           DISK    KS
# 4  New York Worlds Fair             NaN          LIGHT    NY
#
#                  Time week_day
# 0 1930-06-01 22:00:00   Sunday
# 1 1930-06-30 20:00:00   Monday
# 2 1931-02-15 14:00:00   Sunday
# 3 1931-06-01 13:00:00   Monday
# 4 1933-04-18 19:00:00  Tuesday

# %%
df[df.week_day.isin(['Sunday','Saturday'])].week_day.value_counts()
# Out:
# Sunday      2689
# Saturday    2687
# Name: week_day, dtype: int64

# %%
df.Time.dt.year.unique()
# Out:
# array([1930, 1931, 1933, 1934, 1935, 1936, 1937, 1939, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000], dtype=int64)

# %%
df.Time.dt.year.value_counts()
# Out:
# 1999    2774
# 2000    2635
# 1998    1743
# 1995    1344
# 1997    1237
# 1996     851
# 1994     406
# 1978     326
# 1975     312
# 1993     292
# 1976     281
# 1974     261
# 1977     258
# 1989     247
# 1992     245
# 1980     244
# 1990     237
# 1979     237
# 1988     232
# 1973     227
# 1991     220
# 1968     218
# 1985     211
# 1987     210
# 1966     203
# 1967     196
# 1965     195
# 1986     186
# 1982     186
# 1984     177
#         ...
# 1957      78
# 1962      72
# 1960      67
# 1959      57
# 1954      55
# 1958      53
# 1952      52
# 1961      50
# 1956      46
# 1947      41
# 1953      36
# 1955      33
# 1950      31
# 1951      21
# 1949      19
# 1945       9
# 1948       9
# 1944       8
# 1946       8
# 1943       5
# 1939       3
# 1942       3
# 1931       2
# 1930       2
# 1937       2
# 1941       2
# 1936       2
# 1935       1
# 1934       1
# 1933       1
# Name: Time, Length: 68, dtype: int64

# %%
df['year']=df.Time.dt.year
df.Time.dt.year.unique()
# Out:
# array([1930, 1931, 1933, 1934, 1935, 1936, 1937, 1939, 1941, 1942, 1943,
#        1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954,
#        1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965,
#        1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976,
#        1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987,
#        1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998,
#        1999, 2000], dtype=int64)

# %%
t=pd.to_datetime('1999/1/30')

# %%
t
# Out:
# Timestamp('1999-01-30 00:00:00')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df[df.week_day.isin(['Sunday','Saturday'])].week_day.value_counts()
# Out:
# Sunday      2689
# Saturday    2687
# Name: week_day, dtype: int64

# %%
df[df.week_day.isin(['Monday','Thursday'])].week_day.value_counts()
# Out:
# Thursday    2598
# Monday      2300
# Name: week_day, dtype: int64

# %%
df.week_day.value_counts().plot(kind='bar')#,cmap='winter'
plt.grid()

# %%
t1=pd.to_datetime('1999/6/30')

# %%
df.City.value_counts()
# Out:
# Seattle                              187
# New York City                        161
# Phoenix                              137
# Houston                              108
# Las Vegas                            105
# Portland                             102
# San Diego                            101
# Los Angeles                           98
# Chicago                               73
# Austin                                62
# Miami                                 60
# Tucson                                58
# Columbus                              55
# Albuquerque                           54
# Tacoma                                52
# Dallas                                52
# San Francisco                         51
# St. Louis                             51
# Spokane                               49
# Auburn                                48
# Salem                                 48
# Jacksonville                          48
# Sacramento                            46
# ...

# %%
t1=pd.to_datetime('1999/6/30')
t1
# Out:
# Timestamp('1999-06-30 00:00:00')

# %%
df.City.value_counts()
# Out:
# Seattle                              187
# New York City                        161
# Phoenix                              137
# Houston                              108
# Las Vegas                            105
# Portland                             102
# San Diego                            101
# Los Angeles                           98
# Chicago                               73
# Austin                                62
# Miami                                 60
# Tucson                                58
# Columbus                              55
# Albuquerque                           54
# Tacoma                                52
# Dallas                                52
# San Francisco                         51
# St. Louis                             51
# Spokane                               49
# Auburn                                48
# Salem                                 48
# Jacksonville                          48
# Sacramento                            46
# ...

# %%
df[df.Time.dt.year.isin(range(1930,2000))].Time.dt.year.value_counts().plot(kind='bar')

# %%
t1=pd.to_datetime('1999/6/30')

# %%
#df[df.Time>t1]
# Out:
#                          City Colors Reported Shape Reported State  \
# 13803             Cherry Hill             NaN           OVAL    NJ
# 13804                  Tacoma             NaN            NaN    WA
# 13805              Carrollton             NaN         SPHERE    MO
# 13806                 Lombard             NaN         SPHERE    IL
# 13807             Port Isabel             NaN           OVAL    TX
# 13808             Mississippi          ORANGE          LIGHT    MS
# 13809  Herron Lake State Park             NaN          CIGAR    NM
# 13810               Morganton             NaN        DIAMOND    NC
# 13811                 Phoenix             NaN            NaN    AZ
# 13812                Florence             NaN          CIGAR    OR
# 13813           Junction City             NaN          LIGHT    AR
# 13814              Birmingham             NaN          FLASH    AL
# 13815               Dannemora          ORANGE            NaN    NY
# ...

# %%
#df.city.value

# %%
df[(df.Time>=t)&(df.Time<t1)].shape
# Out:
# (848, 8)

# %%
df.shape
# Out:
# (18241, 8)

# %%
#df.loc[df[df.Time>=t].index.tolist(),['city','state','Time']].head()
index=df[df.Time>=t].index.tolist()
df.iloc[index,[0,3,4]].head()
#index
# Out:
#                City State                Time
# 12954  Palm Springs    CA 1999-01-30 05:25:00
# 12955     Red Bluff    CA 1999-01-30 23:30:00
# 12956      Riverton    WY 1999-01-31 19:30:00
# 12957  Lake Charles    LA 1999-01-31 22:02:00
# 12958     Flagstaff    AZ 1999-02-01 00:00:00

# %%
df.Time.max()
# Out:
# Timestamp('2000-12-31 23:59:00')

# %%
df.Time.min
# Out:
# <bound method Series.min of 0       1930-06-01 22:00:00
# 1       1930-06-30 20:00:00
# 2       1931-02-15 14:00:00
# 3       1931-06-01 13:00:00
# 4       1933-04-18 19:00:00
# 5       1934-09-15 15:30:00
# 6       1935-06-15 00:00:00
# 7       1936-07-15 00:00:00
# 8       1936-10-15 17:00:00
# 9       1937-06-15 00:00:00
# 10      1937-08-15 21:00:00
# 11      1939-06-01 20:00:00
# 12      1939-06-30 20:00:00
# 13      1939-07-07 02:00:00
# 14      1941-06-01 13:00:00
# 15      1941-07-02 11:30:00
# 16      1942-02-25 00:00:00
# 17      1942-06-01 22:30:00
# 18      1942-07-15 01:00:00
# 19      1943-04-30 23:00:00
# 20      1943-06-01 15:00:00
# 21      1943-08-15 00:00:00
# 22      1943-08-15 00:00:00
# 23      1943-10-15 11:00:00
# 24      1944-01-01 10:00:00
# 25      1944-01-01 12:00:00
# 26      1944-01-01 12:00:00
# 27      1944-04-02 11:00:00
# 28      1944-06-01 12:00:00
# 29      1944-06-30 10:00:00
#                 ...
# 18211   2000-12-28 18:00:00
# ...

# %%
df.Time.sort_values(ascending=False)[:3]
# Out:
# 18240   2000-12-31 23:59:00
# 18239   2000-12-31 23:45:00
# 18238   2000-12-31 23:45:00
# Name: Time, dtype: datetime64[ns]

# %%
df[df.Time.dt.year.isin(range(1989,2000))].Time.dt.year.value_counts().sort_index().plot(kind='bar')

# %%
#df.Time.hist(bins=6)
df[df.Time.dt.year.isin(range(1989,2000))].Time.dt.year.value_counts()
#df[df.Time.dt.year.isin(range(1989,2000))].Time.dt.year.value_counts().sort_index().plot(kind='bar')
# Out:
# 1999    2774
# 1998    1743
# 1995    1344
# 1997    1237
# 1996     851
# 1994     406
# 1993     292
# 1989     247
# 1992     245
# 1990     237
# 1991     220
# Name: Time, dtype: int64

# %%
df.State.isnull().sum()
# Out:
# 0

# %%
df.State.isnull().count()
# Out:
# 18241

# %%
df.shape
# Out:
# (18241, 8)

# %%
df.year.value_counts()[list(range(1989,2000))].plot(kind='bar')
