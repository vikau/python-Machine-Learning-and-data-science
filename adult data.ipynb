# %%
import pandas as pd 
adult= pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\adult.csv",header=None,na_values=" ?")

# %%
adult
# Out:
#        0                  1       2              3   4   \
# 0      39          State-gov   77516      Bachelors  13
# 1      50   Self-emp-not-inc   83311      Bachelors  13
# 2      38            Private  215646        HS-grad   9
# 3      53            Private  234721           11th   7
# 4      28            Private  338409      Bachelors  13
# 5      37            Private  284582        Masters  14
# 6      49            Private  160187            9th   5
# 7      52   Self-emp-not-inc  209642        HS-grad   9
# 8      31            Private   45781        Masters  14
# 9      42            Private  159449      Bachelors  13
# 10     37            Private  280464   Some-college  10
# 11     30          State-gov  141297      Bachelors  13
# 12     23            Private  122272      Bachelors  13
# 13     32            Private  205019     Assoc-acdm  12
# 14     40            Private  121772      Assoc-voc  11
# 15     34            Private  245487        7th-8th   4
# ...

# %%
adult.isnull().sum()
# Out:
# 0        0
# 1     3672
# 2        0
# 3        0
# 4        0
# 5        0
# 6     3686
# 7        0
# 8        0
# 9        0
# 10       0
# 11       0
# 12       0
# 13    1166
# 14       0
# dtype: int64

# %%
adult.columns=['age','workclass','fnlwgt','education','education.num','material_status','occupation','relationship','race',
            'gender','capital gain','capital less','hour-per-week','native-country','income']

# %%
adult.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#        material_status          occupation    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital gain  capital less  hour-per-week  native-country  income
# 0          2174             0             40   United-States   <=50K
# ...

# %%
adult.shape
# Out:
# (65122, 15)

# %%
adult.isnull().sum()
# Out:
# age                   0
# workclass          3672
# fnlwgt                0
# education             0
# education.num         0
# material_status       0
# occupation         3686
# relationship          0
# race                  0
# gender                0
# capital gain          0
# capital less          0
# hour-per-week         0
# native-country     1166
# income                0
# dtype: int64

# %%
adult.income.value_counts()
# Out:
#  <=50K    49440
#  >50K     15682
# Name: income, dtype: int64

# %%
adult.dropna(inplace=True)

# %%
adult.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# education.num      0
# material_status    0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital gain       0
# capital less       0
# hour-per-week      0
# native-country     0
# income             0
# dtype: int64

# %%
#adult.fillna({'age':adult.age.mean(),'course':adult.counts.value_counts().index[0]},inplace=True)

# %%
#adult.get_dummies

# %%
adult.income=adult.income.map({' <=50k':0,' >50k':1})

# %%
adult.income.value_counts()
# Out:
# Series([], Name: income, dtype: int64)

# %%
adult.shape
# Out:
# (60324, 15)

# %%
x=adult.drop('income',axis=1)
y=adult.income

# %%
x.head()
# Out:
#    age          workclass  fnlwgt   education  education.num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#        material_status          occupation    relationship    race   gender  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital gain  capital less  hour-per-week  native-country
# 0          2174             0             40   United-States
# ...

# %%
y.head()
# Out:
# 0   NaN
# 1   NaN
# 2   NaN
# 3   NaN
# 4   NaN
# Name: income, dtype: float64

# %%
adult.education.unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' 7th-8th', ' Doctorate',
#        ' Assoc-voc', ' Prof-school', ' 5th-6th', ' 10th', ' Preschool',
#        ' 12th', ' 1st-4th'], dtype=object)

# %%
adult['native-country'].value_counts()
# Out:
#  United-States                 55008
#  Mexico                         1220
#  Philippines                     376
#  Germany                         256
#  Puerto-Rico                     218
#  Canada                          214
#  India                           200
#  El-Salvador                     200
#  Cuba                            184
#  England                         172
#  Jamaica                         160
#  South                           142
#  Italy                           136
#  China                           136
#  Dominican-Republic              134
#  Vietnam                         128
#  Guatemala                       126
#  Japan                           118
#  Columbia                        112
#  Poland                          112
#  Haiti                            84
#  Iran                             84
#  Taiwan                           84
#  Portugal                         68
#  Nicaragua                        66
# ...

# %%
for i in adult.columns:
    if adult[i].dtypes=='object':
        j=adult[i].nunique()
        print(" unique_feature {} has {} categories".formates)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-02cf03b354c1> in <module>()
#       2     if adult[i].dtypes=='object':
#       3         j=adult[i].nunique()
# ----> 4         print(" unique_feature {} has {} categories".formates)
#
# AttributeError: 'str' object has no attribute 'formates'

# %%
for col_name in adult.columns:
    if adult[col_names].dtypes=='object':
        unique_cat=adult[col_name].nonuque()
        print(" feature {} has {} unique_categories".format)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-69-b89edb9fe775> in <module>()
#       1 for col_name in adult.columns:
# ----> 2     if adult[col_names].dtypes=='object':
#       3         unique_cat=adult[col_name].nonuque()
#       4         print(" feature {} has {} unique_categories".format)
#
# NameError: name 'col_names' is not defined

# %%
adult['native-country']=['US' if x=='United-state' size 'eithers' for x in adult['native-country']]
# Out:
#   File "<ipython-input-40-43bfa3eb51d8>", line 1
#     adult['native-country']=['US' if x=='United-state' size 'eithers' for x in adult['native-country']]
#                                                           ^
# SyntaxError: invalid syntax

# %%
adult['native-country'].value_counts()
# Out:
#  United-States                 55008
#  Mexico                         1220
#  Philippines                     376
#  Germany                         256
#  Puerto-Rico                     218
#  Canada                          214
#  India                           200
#  El-Salvador                     200
#  Cuba                            184
#  England                         172
#  Jamaica                         160
#  South                           142
#  Italy                           136
#  China                           136
#  Dominican-Republic              134
#  Vietnam                         128
#  Guatemala                       126
#  Japan                           118
#  Columbia                        112
#  Poland                          112
#  Haiti                            84
#  Iran                             84
#  Taiwan                           84
#  Portugal                         68
#  Nicaragua                        66
# ...

# %%
c=adult.select_dtypes(include=['object'])

# %%
c.columns
# Out:
# Index(['workclass', 'education', 'material_status', 'occupation',
#        'relationship', 'race', 'gender', 'native-country'],
#       dtype='object')

# %%
x1=pd.get_dummies(adult[c.columns])

# %%
x1.shape
# Out:
# (60324, 98)

# %%
new_adult=pd.concat([x1.adult])

# %%
t= pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\txt.adult")

# %%
t

# %%
t.fillna({'age':t.age.mean(),'course':t.counts.value_counts().index[0]},inplace=True)

# %%
txt.adult['size']
