# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
df=pd.read_csv("C:\\Users\\hp\\Desktop\\python\\New folder\\ml\\dataset\\data.csv")
df
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# 5         80175.754159             4.988408                   6.104512
# 6         64698.463428             6.025336                   8.147760
# 7         78394.339278             6.989780                   6.620478
# 8         59927.660813             5.362126                   6.393121
# 9         81885.927184             4.423672                   8.167688
# 10        80527.472083             8.093513                   5.042747
# 11        50593.695497             4.496513                   7.467627
# ...

# %%
df.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Avg. Area Income                float64
# Avg. Area House Age             float64
# Avg. Area Number of Rooms       float64
# Avg. Area Number of Bedrooms    float64
# Area Population                 float64
# Price                           float64
# Address                          object
# dtype: object

# %%
#import seborn as sb

# %%
x=df.iloc[:,:5]
x
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# 5         80175.754159             4.988408                   6.104512
# 6         64698.463428             6.025336                   8.147760
# 7         78394.339278             6.989780                   6.620478
# 8         59927.660813             5.362126                   6.393121
# 9         81885.927184             4.423672                   8.167688
# 10        80527.472083             8.093513                   5.042747
# 11        50593.695497             4.496513                   7.467627
# ...

# %%
y=df['Price']
y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
# 5       1.068138e+06
# 6       1.502056e+06
# 7       1.573937e+06
# 8       7.988695e+05
# 9       1.545155e+06
# 10      1.707046e+06
# 11      6.637324e+05
# 12      1.042814e+06
# 13      1.291332e+06
# 14      1.402818e+06
# 15      1.306675e+06
# 16      1.556787e+06
# 17      5.284852e+05
# 18      1.019426e+06
# 19      1.030591e+06
# 20      2.146925e+06
# 21      9.292476e+05
# 22      7.188872e+05
# 23      7.439998e+05
# 24      8.957371e+05
# 25      1.453975e+06
# 26      1.125693e+06
# 27      9.754295e+05
# 28      1.240764e+06
# 29      1.577018e+06
#             ...
# 4970    1.120943e+06
# 4971    1.111307e+06
# 4972    1.736402e+06
# 4973    1.340770e+06
# 4974    8.013486e+05
# 4975    1.324382e+06
# 4976    1.340344e+06
# 4977    1.518478e+06
# 4978    1.910585e+06
# 4979    1.823498e+06
# 4980    1.406865e+06
# 4981    1.203850e+06
# ...

# %%
x.shape
# Out:
# (5000, 5)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.4,random_state=11)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#import seaborn as sb

# %%
lm.coef_
# Out:
# array([2.15274941e+01, 1.65577182e+05, 1.21888625e+05, 4.98987372e+02,
#        1.51944000e+01])

# %%
lm.intercept_
# Out:
# -2636387.8084529927

# %%
import seaborn as sb

# %%
pred1=lm.predict(x_test)

# %%
sb.distplot((y_test-pred1))

# %%
#y_test
#from sklearn.matrics import r2_score

# %%
#residual looks as a normally distributed which is a very good sign if we have normally 
#distributed residuals it means our model is a correct choice for the data

# %%
#normal distriibution
#the mean medium and mode are equal
#Bell shape ansd is symmetric about the mean
#the total area that lies under the curve is one or 100%

# %%
#from  sklearn.metrics import r2_score

# %%
#r2_score(y_test,predict)

# %%
from sklearn.datasets import load_boston

# %%
boston=load_boston()

# %%
print (boston.DESCR)
boston.feature_names
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
x1=boston.data
y1=boston.target

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=.3,random_state=11)

# %%
lml=LinearRegression()

# %%
lml.fit(x1_train,y1_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred2=lml.predict(x1_test)

# %%
lml.score(x1_train,y1_train)
# Out:
# 0.7441201016077185

# %%
import seaborn as sb

# %%
sb.distplot((y1_test-pred2))

# %%
from sklearn.model_selection import train_test_split

# %%
x3=boston.data
y3=boston.target

# %%
x3_train,x3_test,y3_train,y3_test=train_test_split(x3,y3,test_size=.6,random_state=17)

# %%
lmll=LinearRegression()

# %%
lmll.fit(x3_train,y3_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pred3=lmll.predict(x3_test)

# %%
lmll.score(x3_train,y3_train)
# Out:
# 0.8029525967258497

# %%
import seaborn as sb

# %%
sb.distplot((y3_test-pred3))
