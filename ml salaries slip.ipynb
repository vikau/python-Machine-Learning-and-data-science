# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\mlbsalaries.csv")

# %%
df
# Out:
#        Year              Player    Salary           Position  \
# 0      1988           Mike Witt   1400000            Pitcher
# 1      1988     George Hendrick    989333         Outfielder
# 2      1988         Chili Davis    950000         Outfielder
# 3      1988       Brian Downing    900000  Designated Hitter
# 4      1988           Bob Boone    883000            Catcher
# 5      1988          Johnny Ray    857000     Second Baseman
# 6      1988           Dan Petry    785000            Pitcher
# 7      1988       Butch Wynegar    733333            Catcher
# 8      1988      Dick Schofield    552222          Shortstop
# 9      1988         Greg Minton    525000            Pitcher
# 10     1988   Tony Rafael Armas    425000         Outfielder
# 11     1988        Wally Joyner    340000      First Baseman
# 12     1988      Kirk McCaskill    262000            Pitcher
# 13     1988         Jack Howell    200000      Third Baseman
# ...

# %%
df.shape
# Out:
# (19543, 5)

# %%
df.head()
# Out:
#    Year           Player   Salary           Position                Team
# 0  1988        Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1  1988  George Hendrick   989333         Outfielder  Los Angeles Angels
# 2  1988      Chili Davis   950000         Outfielder  Los Angeles Angels
# 3  1988    Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4  1988        Bob Boone   883000            Catcher  Los Angeles Angels

# %%
df.Year.value_counts()
# Out:
# 1990    972
# 1999    919
# 2008    858
# 2001    857
# 2002    849
# 2007    848
# 1998    846
# 2011    843
# 2000    843
# 2004    833
# 2005    831
# 2010    828
# 2003    826
# 2006    823
# 2009    818
# 1995    805
# 1993    786
# 1997    773
# 1996    768
# 1992    753
# 1994    748
# 1991    720
# 1989    710
# 1988    686
# Name: Year, dtype: int64

# %%
df.Position.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0                  Pitcher
# 1               Outfielder
# 2               Outfielder
# 3        Designated Hitter
# 4                  Catcher
# 5           Second Baseman
# 6                  Pitcher
# 7                  Catcher
# 8                Shortstop
# 9                  Pitcher
# 10              Outfielder
# 11           First Baseman
# 12                 Pitcher
# 13           Third Baseman
# 14              Outfielder
# 15                 Pitcher
# 16          Second Baseman
# 17                 Pitcher
# 18                 Catcher
# 19                 Pitcher
# 20                 Pitcher
# 21              Outfielder
# 22                 Pitcher
# 23                 Pitcher
# 24              Outfielder
# 25                 Pitcher
# 26                 Pitcher
# 27                 Pitcher
# 28                 Pitcher
# 29              Outfielder
#                ...
# 19513        Third Baseman
# 19514              Pitcher
# ...

# %%
yr_2010=df[df.Year==2010]

# %%
yr_2010.shape
# Out:
# (828, 5)

# %%
yr_2010.head()
# Out:
#        Year         Player    Salary    Position                Team
# 17872  2010   Torii Hunter  18500000  Outfielder  Los Angeles Angels
# 17873  2010    Bobby Abreu   9000000  Outfielder  Los Angeles Angels
# 17874  2010  Brian Fuentes   9000000     Pitcher  Los Angeles Angels
# 17875  2010   Scott Kazmir   8000000     Pitcher  Los Angeles Angels
# 17876  2010   Joel Pineiro   8000000     Pitcher  Los Angeles Angels

# %%
yr_2010.loc[yr_2010.Salary.sort_values(ascending=False).index,['Player','Salary']].head(5)
# Out:
#                Player    Salary
# 18675  Alex Rodriguez  33000000
# 18676     CC Sabathia  24285714
# 18677     Derek Jeter  22600000
# 18678   Mark Teixeira  20625000
# 18263   Johan Santana  20144707

# %%
group_yr=df.groupby('Year')

# %%
group_yr.Salary.max()
# Out:
# Year
# 1988     2360714
# 1989     2766666
# 1990     3200000
# 1991     3800000
# 1992     6100000
# 1993     6200000
# 1994     6300000
# 1995     9237500
# 1996     9237500
# 1997    10000000
# 1998    10000000
# 1999    11949794
# 2000    15714286
# 2001    22000000
# 2002    22000000
# 2003    22000000
# 2004    22500000
# 2005    26000000
# 2006    21680727
# 2007    23428571
# 2008    28000000
# 2009    33000000
# 2010    33000000
# 2011    32000000
# Name: Salary, dtype: int64

# %%
group_yr.head()
# Out:
#        Year               Player    Salary           Position  \
# 0      1988            Mike Witt   1400000            Pitcher
# 1      1988      George Hendrick    989333         Outfielder
# 2      1988          Chili Davis    950000         Outfielder
# 3      1988        Brian Downing    900000  Designated Hitter
# 4      1988            Bob Boone    883000            Catcher
# 686    1989            Mike Witt   1400000            Pitcher
# 687    1989          Chili Davis   1275000         Outfielder
# 688    1989        Brian Downing   1250000         Outfielder
# 689    1989        Bert Blyleven   1225000            Pitcher
# 690    1989        Lance Parrish   1000000            Catcher
# 1396   1990        Lance Parrish   1916667            Catcher
# 1397   1990        Mark Langston   1800000            Pitcher
# 1398   1990         Wally Joyner   1750000      First Baseman
# 1399   1990          Chili Davis   1375000         Outfielder
# ...

# %%
group_yr=df.groupby('Year')
d=pd.DataFrame()
for k in group_yr:
    d=d.append(k[1].sort_values('Salary',ascending=False).head(1))

# %%
d
# Out:
#        Year             Player    Salary           Position  \
# 321    1988        Gary Carter   2360714            Catcher
# 908    1989     Orel Hershiser   2766666            Pitcher
# 1580   1990        Robin Yount   3200000         Outfielder
# 2590   1991  Darryl Strawberry   3800000         Outfielder
# 3441   1992      Bobby Bonilla   6100000         Outfielder
# 4214   1993      Bobby Bonilla   6200000         Outfielder
# 4977   1994      Bobby Bonilla   6300000      Third Baseman
# 6068   1995      Cecil Fielder   9237500      First Baseman
# 6840   1996      Cecil Fielder   9237500      First Baseman
# 7666   1997       Albert Belle  10000000         Outfielder
# 8090   1998     Gary Sheffield  10000000         Outfielder
# 9067   1999       Albert Belle  11949794         Outfielder
# 9743   2000     Kevin J. Brown  15714286            Pitcher
# 10903  2001     Alex Rodriguez  22000000          Shortstop
# 11752  2002     Alex Rodriguez  22000000          Shortstop
# ...

# %%
group_yr=df.groupby('Year')
d=pd.DataFrame()
for k in group_yr:
    d=d.append(k[1].sort_values('Salary',ascending=True).head(1))

# %%
d
# Out:
#        Year            Player  Salary        Position                   Team
# 395    1988  Jose J. Bautista   62500         Pitcher      Baltimore Orioles
# 1395   1989   Bernie Williams   68000      Outfielder       New York Yankees
# 1881   1990      Keith Miller  100000      Outfielder          New York Mets
# 2727   1991       Rick Cerone  100000         Catcher          New York Mets
# 3840   1992  Andy Stankiewicz  109000  Second Baseman       New York Yankees
# 4626   1993   Gerald Williams  109000      Outfielder       New York Yankees
# 5000   1994    Kelly Stinnett  109000         Catcher          New York Mets
# 6179   1995    Mariano Rivera  109000         Pitcher       New York Yankees
# 6947   1996         Matt Luke  109000      Outfielder       New York Yankees
# 7334   1997      Steve Bieser  150000      Outfielder          New York Mets
# 8261   1998     Desi Relaford  170000       Shortstop  Philadelphia Phillies
# ...

# %%
for i in group_yr:
    print (i[1])
# Out:
#      Year               Player   Salary           Position                Team
# 0    1988            Mike Witt  1400000            Pitcher  Los Angeles Angels
# 1    1988      George Hendrick   989333         Outfielder  Los Angeles Angels
# 2    1988          Chili Davis   950000         Outfielder  Los Angeles Angels
# 3    1988        Brian Downing   900000  Designated Hitter  Los Angeles Angels
# 4    1988            Bob Boone   883000            Catcher  Los Angeles Angels
# 5    1988           Johnny Ray   857000     Second Baseman  Los Angeles Angels
# 6    1988            Dan Petry   785000            Pitcher  Los Angeles Angels
# 7    1988        Butch Wynegar   733333            Catcher  Los Angeles Angels
# 8    1988       Dick Schofield   552222          Shortstop  Los Angeles Angels
# 9    1988          Greg Minton   525000            Pitcher  Los Angeles Angels
# 10   1988    Tony Rafael Armas   425000         Outfielder  Los Angeles Angels
# ...
