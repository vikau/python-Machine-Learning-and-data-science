# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\drinks.csv")

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
df
# Out:
#                   country  beer_servings  spirit_servings  wine_servings  \
# 0             Afghanistan              0                0              0
# 1                 Albania             89              132             54
# 2                 Algeria             25                0             14
# 3                 Andorra            245              138            312
# 4                  Angola            217               57             45
# 5       Antigua & Barbuda            102              128             45
# 6               Argentina            193               25            221
# 7                 Armenia             21              179             11
# 8               Australia            261               72            212
# 9                 Austria            279               75            191
# 10             Azerbaijan             21               46              5
# 11                Bahamas            122              176             51
# ...

# %%
df.shape
# Out:
# (193, 6)

# %%
df.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
df.groupby('continent').country.value_counts()
# Out:
# continent      country
# Africa         Algeria                     1
#                Angola                      1
#                Benin                       1
#                Botswana                    1
#                Burkina Faso                1
#                Burundi                     1
#                Cabo Verde                  1
#                Cameroon                    1
#                Central African Republic    1
#                Chad                        1
#                Comoros                     1
#                Congo                       1
#                Cote d'Ivoire               1
#                DR Congo                    1
#                Djibouti                    1
#                Egypt                       1
#                Equatorial Guinea           1
#                Eritrea                     1
#                Ethiopia                    1
#                Gabon                       1
# ...

# %%
df[df.continent=='South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# ...

# %% [markdown]
# # find average beer serving by each continent

# %%
df.groupby('continent').beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
df.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %% [markdown]
# # find maximum beer_serverings country by each continents

# %%
df.groupby('continent').beer_servings.max()
# Out:
# continent
# Africa           376
# Asia             247
# Europe           361
# North America    285
# Oceania          306
# South America    333
# Name: beer_servings, dtype: int64

# %% [markdown]
# # df.groupby('continent').beer_servings.max()

# %%
df2=pd.DataFrame()
for k in df.groupby('continent'):
    index=k[1].sort_values('beer_servings',ascending=False).index
    d=df.iloc[index,[0,1,5]]
    df2=df2.append(d.head(1))

# %%
df2
# Out:
#                 country  beer_servings      continent
# 117             Namibia            376         Africa
# 141  Russian Federation            247           Asia
# 45       Czech Republic            361         Europe
# 130              Panama            285  North America
# 129               Palau            306        Oceania
# 188           Venezuela            333  South America

# %% [markdown]
# # plot maximum and minmum beer servings by each continent

# %%
df.groupby('continent').mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
df.groupby('continent').beer_servings.agg(['min','max','mean']).plot(kind='bar')

# %%
df[df.continent=='Africa'].beer_servings.mean()
# Out:
# 61.471698113207545

# %%
df.loc[[df.beer_servings.idxmax()]]
# Out:
#      country  beer_servings  spirit_servings  wine_servings  \
# 117  Namibia            376                3              1
#
#      total_litres_of_pure_alcohol continent
# 117                           6.8    Africa

# %%
df.groupby('continent').beer_servings.agg(['count','min','max','mean']).plot(kind='bar')

# %%
df.groupby('continent').beer_servings.agg(['count','min','max','mean']).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002893000CEF0>,
# ...
#       dtype=object)

# %%
df.groupby('continent').beer_servings.agg(['count']).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002893145BB38>]],
#       dtype=object)

# %%
df.groupby('continent').beer_servings.agg(['mean']).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000028931515898>]],
#       dtype=object)

# %%
df.groupby('continent').beer_servings.agg(['max']).hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000289315488D0>]],
#       dtype=object)

# %%
df.Fare.hist(bin=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-75-43f489c46e33> in <module>()
# ----> 1 df.Fare.hist(bin=10)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Fare'

# %%
df.Fare.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-c64f0f0537a4> in <module>()
# ----> 1 df.Fare.plot(kind='bar')
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Fare'

# %%
df.Age.hist(bins=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-3bfacd3d0262> in <module>()
# ----> 1 df.Age.hist(bins=20)
#
# C:\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Age'
