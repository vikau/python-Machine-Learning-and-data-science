# %%
import pandas as pd 
movies= pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\movies.csv")

# %%
import pandas as pd

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.shape
# Out:
# (979, 6)

# %%
movies [movies.duration>200]
# Out:
#      star_rating                                          title  \
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# ...

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.loc[movies[movies['duration']>=200].index,['title','duration']]
# Out:
#                                              title  duration
# 2                           The Godfather: Part II       200
# 7    The Lord of the Rings: The Return of the King       201
# 17                                   Seven Samurai       207
# 78                     Once Upon a Time in America       229
# 85                              Lawrence of Arabia       216
# 142              Lagaan: Once Upon a Time in India       224
# 157                             Gone with the Wind       238
# 204                                        Ben-Hur       212
# 445                           The Ten Commandments       220
# 476                                         Hamlet       242
# 630                                      Malcolm X       202
# 767                It's a Mad, Mad, Mad, Mad World       205

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
movies.genre.value_counts().plot(kind='bar')
#plt.show()

# %%
movies[movies['duration']>=200].shape
# Out:
# (12, 6)

# %%
m=movies.sort_values(by='duration',ascending=False).index[:3]
movies.iloc[m,[1,4]]
# Out:
#                            title  duration
# 476                       Hamlet       242
# 157           Gone with the Wind       238
# 78   Once Upon a Time in America       229

# %%
movies.loc[movies.sort_values('duration',ascending=False).index.tolist(),['title','duration']].head(3)
# Out:
#                            title  duration
# 476                       Hamlet       242
# 157           Gone with the Wind       238
# 78   Once Upon a Time in America       229

# %%
m=movies.sort_values('duration',ascending=False).index.tolist()[:3]

# %%
movies.iloc[m,[1,4]]
# Out:
#                            title  duration
# 476                       Hamlet       242
# 157           Gone with the Wind       238
# 78   Once Upon a Time in America       229

# %%
movies[(movies.genre=='Action') & (movies.star_rating>8.0)]
# Out:
#      star_rating                                           title  \
# 3            9.0                                 The Dark Knight
# 11           8.8                                       Inception
# 12           8.8  Star Wars: Episode V - The Empire Strikes Back
# 19           8.7                                       Star Wars
# 20           8.7                                      The Matrix
# 36           8.6                             Saving Private Ryan
# 37           8.6                         Raiders of the Lost Ark
# 43           8.5                           The Dark Knight Rises
# 44           8.5                                       Gladiator
# 45           8.5                      Terminator 2: Judgment Day
# 75           8.4                                          Aliens
# 80           8.4      Star Wars: Episode VI - Return of the Jedi
# 82           8.4                                      Braveheart
# ...

# %%
movies[movies.actors_list.str.contains('Amir Khan',case=False)]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
movies.genre.value_counts()[['Drama','Crime','Action']]
#movies.dtypes
# Out:
# Drama     278
# Crime     124
# Action    136
# Name: genre, dtype: int64

# %%
movies[(movies.duration >= 200) & ((movies.genre=='Drama') | (movies.genre=='Crime'))].head()
# Out:
#      star_rating                        title content_rating  genre  duration  \
# 2            9.1       The Godfather: Part II              R  Crime       200
# 17           8.7                Seven Samurai        UNRATED  Drama       207
# 78           8.4  Once Upon a Time in America              R  Crime       229
# 157          8.2           Gone with the Wind              G  Drama       238
# 476          7.8                       Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
movies.duration.sort_values(ascending=False)
movies.sort_values('duration',ascending=False)
# Out:
#      star_rating                                          title  \
# 476          7.8                                         Hamlet
# 157          8.2                             Gone with the Wind
# 78           8.4                    Once Upon a Time in America
# 142          8.3              Lagaan: Once Upon a Time in India
# 445          7.9                           The Ten Commandments
# 85           8.4                             Lawrence of Arabia
# 204          8.1                                        Ben-Hur
# 17           8.7                                  Seven Samurai
# 767          7.6                It's a Mad, Mad, Mad, Mad World
# 630          7.7                                      Malcolm X
# 7            8.9  The Lord of the Rings: The Return of the King
# 2            9.1                         The Godfather: Part II
# 335          8.0                                 Doctor Zhivago
# 385          8.0                                      Spartacus
# ...

# %%
import re

def check(x):
    m=re.search('^once',x,re.I)
    if m:
        return True
    else:
        return False
    
#movies[movies.title.str.startswith('Once')]
movies[movies.title.apply(check)]

#movies[movies.actors_list.str.contains('amir khan',case=False)]
# Out:
#      star_rating                         title content_rating    genre  \
# 26           8.6  Once Upon a Time in the West          PG-13  Western
# 78           8.4   Once Upon a Time in America              R    Crime
# 402          7.9                          Once              R    Drama
#
#      duration                                        actors_list
# 26        175  [u'Henry Fonda', u'Charles Bronson', u'Claudia...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 402        85  [u'Glen Hansard', u'Mark\xe9ta Irglov\xe1', u'...

# %%
movies.isnull().sum()
movies[movies.content_rating.isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
#movies.genre.value_counts()
movies.select_dtypes(include=['object'])
#movies.select_dtypes(exclude=['int64'])
#movies.select_dtypes(include=['int64'])
#movies.actors_list[0]
# Out:
#                                                  title content_rating  \
# 0                             The Shawshank Redemption              R
# 1                                        The Godfather              R
# 2                               The Godfather: Part II              R
# 3                                      The Dark Knight          PG-13
# 4                                         Pulp Fiction              R
# 5                                         12 Angry Men      NOT RATED
# 6                       The Good, the Bad and the Ugly      NOT RATED
# 7        The Lord of the Rings: The Return of the King          PG-13
# 8                                     Schindler's List              R
# 9                                           Fight Club              R
# 10   The Lord of the Rings: The Fellowship of the Ring          PG-13
# 11                                           Inception          PG-13
# ...

# %%
movies[movies.genre.isin(['Drama','Crime','Action'])][:10]
# Out:
#     star_rating                                           title  \
# 0           9.3                        The Shawshank Redemption
# 1           9.2                                   The Godfather
# 2           9.1                          The Godfather: Part II
# 3           9.0                                 The Dark Knight
# 4           8.9                                    Pulp Fiction
# 5           8.9                                    12 Angry Men
# 9           8.9                                      Fight Club
# 11          8.8                                       Inception
# 12          8.8  Star Wars: Episode V - The Empire Strikes Back
# 13          8.8                                    Forrest Gump
#
#    content_rating   genre  duration  \
# 0               R   Crime       142
# 1               R   Crime       175
# 2               R   Crime       200
# 3           PG-13  Action       152
# 4               R   Crime       154
# 5       NOT RATED   Drama        96
# ...

# %%
movies.iloc[-2]
# Out:
# star_rating                                                     7.4
# title                                                   Poltergeist
# content_rating                                                   PG
# genre                                                        Horror
# duration                                                        114
# actors_list       [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# Name: 977, dtype: object

# %%
movies.iloc[64]
# Out:
# star_rating                                                    8.4
# title                                                       WALL-E
# content_rating                                                   G
# genre                                                    Animation
# duration                                                        98
# actors_list       [u'Ben Burtt', u'Elissa Knight', u'Jeff Garlin']
# Name: 64, dtype: object

# %%
movies[(movies['duration']>60) & (movies['duration']<70) ][:5]
movies[movies.duration.isin(range(60,70))][:10]
# Out:
#      star_rating                        title content_rating    genre  \
# 88           8.4                      The Kid      NOT RATED   Comedy
# 258          8.1  The Cabinet of Dr. Caligari        UNRATED    Crime
# 293          8.1                    Duck Soup         PASSED   Comedy
# 338          8.0          Battleship Potemkin        UNRATED  History
# 389          8.0                       Freaks        UNRATED    Drama
# 742          7.6                    Following              R  Mystery
#
#      duration                                        actors_list
# 88         68  [u'Charles Chaplin', u'Edna Purviance', u'Jack...
# 258        67  [u'Werner Krauss', u'Conrad Veidt', u'Friedric...
# 293        68    [u'Groucho Marx', u'Harpo Marx', u'Chico Marx']
# 338        66  [u'Aleksandr Antonov', u'Vladimir Barsky', u'G...
# 389        64  [u'Wallace Ford', u'Leila Hyams', u'Olga Bacla...
# 742        69  [u'Jeremy Theobald', u'Alex Haw', u'Lucy Russe...

# %%
movies.sort_values('duration',ascending=False).head()
# Out:
#      star_rating                              title content_rating      genre  \
# 476          7.8                             Hamlet          PG-13      Drama
# 157          8.2                 Gone with the Wind              G      Drama
# 78           8.4        Once Upon a Time in America              R      Crime
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 445          7.9               The Ten Commandments       APPROVED  Adventure
#
#      duration                                        actors_list
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...

# %%
#movies.sort_values(['content_rating','duration'])[:5]
#movies.content_rating.value_counts()
movies.duration.value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
# 120    18
# 105    18
# 126    18
# 98     18
# 130    18
# 100    17
# 121    17
# 116    17
# 124    16
# 122    16
# 118    16
# 115    16
# 96     16
# 104    16
# 110    16
# 107    16
# 109    16
# 119    15
# 114    15
# 99     15
# 108    15
# 94     14
# 117    14
# 106    14
# 93     14
#        ..
# 70      1
# 69      1
# 67      1
# 66      1
# 242     1
# 238     1
# 195     1
# 229     1
# 224     1
# 220     1
# 216     1
# 212     1
# 207     1
# 205     1
# 202     1
# 201     1
# 200     1
# 194     1
# 159     1
# 193     1
# 187     1
# 186     1
# 184     1
# 183     1
# 182     1
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
movies.describe()
movies.select_dtypes(include=['object']).describe()
#movies.title.value_counts()
# Out:
#             title content_rating  genre  \
# count         979            976    979
# unique        975             12     16
# top     True Grit              R  Drama
# freq            2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies[movies.actors_list.str.contains('Aamir Khan')]
# Out:
#      star_rating                              title content_rating      genre  \
# 47           8.5                   Taare Zameen Par             PG      Drama
# 60           8.5                           3 Idiots          PG-13     Comedy
# 72           8.4                    Rang De Basanti      NOT RATED      Drama
# 109          8.3                     Dil Chahta Hai      NOT RATED     Comedy
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
#
#      duration                                        actors_list
# 47        165  [u'Darsheel Safary', u'Aamir Khan', u'Tanay Ch...
# 60        170        [u'Aamir Khan', u'Madhavan', u'Mona Singh']
# 72        157    [u'Aamir Khan', u'Soha Ali Khan', u'Siddharth']
# 109       183  [u'Aamir Khan', u'Saif Ali Khan', u'Akshaye Kh...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...

# %%
movies.genre.value_counts()
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# History        1
# Fantasy        1
# Name: genre, dtype: int64

# %%
#EDA
movies.genre.describe()
# Out:
# count       979
# unique       16
# top       Drama
# freq        278
# Name: genre, dtype: object

# %%
movies.genre.unique()
# Out:
# array(['Crime', 'Action', 'Drama', 'Western', 'Adventure', 'Biography',
#        'Comedy', 'Animation', 'Mystery', 'Horror', 'Film-Noir', 'Sci-Fi',
#        'History', 'Thriller', 'Family', 'Fantasy'], dtype=object)

# %%
movies.genre.nunique()
# Out:
# 16

# %%
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
movies.duration.value_counts()
movies['duration'].value_counts()
# Out:
# 112    23
# 113    22
# 102    20
# 101    20
# 129    19
# 120    18
# 105    18
# 126    18
# 98     18
# 130    18
# 100    17
# 121    17
# 116    17
# 124    16
# 122    16
# 118    16
# 115    16
# 96     16
# 104    16
# 110    16
# 107    16
# 109    16
# 119    15
# 114    15
# 99     15
# 108    15
# 94     14
# 117    14
# 106    14
# 93     14
#        ..
# 70      1
# 69      1
# 67      1
# 66      1
# 242     1
# 238     1
# 195     1
# 229     1
# 224     1
# 220     1
# 216     1
# 212     1
# 207     1
# 205     1
# 202     1
# 201     1
# 200     1
# 194     1
# 159     1
# 193     1
# 187     1
# 186     1
# 184     1
# 183     1
# 182     1
# 180     1
# 177     1
# 168     1
# 166     1
# 64      1
# Name: duration, Length: 133, dtype: int64

# %%
# %matplotlib inline
#import matplotlib.pyplot as plt

# %%
movies.genre.value_counts().plot(kind='bar')

# %%
m=movies[(movies.duration>100) & (movies.duration<150)]
m.genre.value_counts().plot(kind='bar')

# %%
m=movies[(movies.duration>100) & (movies.duration<150)]
m.genre.value_counts().plot(kind='bar')

# %%
movies.index
# Out:
# RangeIndex(start=0, stop=979, step=1)

# %%
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
a=[3,4,5]

# %%
z=a

# %%
z.append(10)

# %%
z
# Out:
# [3, 4, 5, 10]

# %%
m=movies

# %%
del m['duration']

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  \
# 0          9.3  The Shawshank Redemption              R   Crime
# 1          9.2             The Godfather              R   Crime
# 2          9.1    The Godfather: Part II              R   Crime
# 3          9.0           The Dark Knight          PG-13  Action
# 4          8.9              Pulp Fiction              R   Crime
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies[movies.content_rating.notnull()].shape
# Out:
# (976, 5)

# %%
movies[movies['content_rating'].isnull()]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre                                        actors_list
# 187  Biography  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
#movies.groupby('genre').size()
movies.groupby('genre').count()
# Out:
#            star_rating  title  content_rating  actors_list
# genre
# Action             136    136             135          136
# Adventure           75     75              74           75
# Animation           62     62              62           62
# Biography           77     77              76           77
# Comedy             156    156             156          156
# Crime              124    124             124          124
# Drama              278    278             278          278
# Family               2      2               2            2
# Fantasy              1      1               1            1
# Film-Noir            3      3               3            3
# History              1      1               1            1
# Horror              29     29              29           29
# Mystery             16     16              16           16
# Sci-Fi               5      5               5            5
# Thriller             5      5               5            5
# ...

# %%
m=movies.sort_value(by='duration',ascending=false).index,['title','duration']].head(3)
# Out:
#   File "<ipython-input-55-07e1db8c340e>", line 1
#     m=movies.sort_value(by='duration',ascending=false).index,['title','duration']].head(3)
#                                                                                  ^
# SyntaxError: invalid syntax

# %%
#cheaps

# %%
#cheaps
import numpy as np
import pandas as pd

# %%
orders=pd.read_csv("C:\\Users\\hp\\Desktop\\pandas_tut\\dataset\\chips.tsv",delimiter="\t")

# %%
orders.item_name.head()
# Out:
# 0             Chips and Fresh Tomato Salsa
# 1                                     Izze
# 2                         Nantucket Nectar
# 3    Chips and Tomatillo-Green Chili Salsa
# 4                             Chicken Bowl
# Name: item_name, dtype: object

# %%
orders.iloc[:5,[0,1,2,4]]
# Out:
#    order_id  quantity                              item_name item_price
# 0         1         1           Chips and Fresh Tomato Salsa     $2.39
# 1         1         1                                   Izze     $3.39
# 2         1         1                       Nantucket Nectar     $3.39
# 3         1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4         2         2                           Chicken Bowl    $16.98

# %%
orders.shape
# Out:
# (4622, 5)

# %%
orders.item_name.str.upper().head(10)
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# 5                             CHICKEN BOWL
# 6                            SIDE OF CHIPS
# 7                            STEAK BURRITO
# 8                         STEAK SOFT TACOS
# 9                            STEAK BURRITO
# Name: item_name, dtype: object

# %%
orders[orders.item_name.str.contains("chicken",case=False)].shape
# Out:
# (1560, 5)

# %%
orders[orders.item_name.str.contains("chicken",case=False)].item_price
# Out:
# 4       $16.98
# 5       $10.98
# 11       $8.75
# 12       $8.75
# 13      $11.25
# 16       $8.49
# 17       $8.49
# 19       $8.75
# 23      $10.98
# 26       $8.49
# 29       $8.49
# 35       $8.75
# 36       $8.75
# 42      $11.25
# 44       $8.75
# 45      $10.98
# 52      $10.98
# 63       $8.75
# 68      $10.98
# 73       $8.75
# 75       $8.75
# 76       $8.75
# 78       $8.75
# 79      $11.25
# 82       $8.75
# 83       $8.75
# 98       $8.75
# 99       $8.75
# 110      $8.75
# 114      $8.49
#          ...
# 4537     $8.75
# 4540    $11.25
# 4543     $8.75
# 4550     $8.75
# 4553    $11.25
# 4555     $8.75
# 4556    $11.25
# 4558     $8.75
# 4559    $11.25
# 4561    $17.50
# 4564    $11.25
# 4566     $8.75
# 4569     $8.75
# 4574     $8.75
# 4576    $11.25
# 4580    $11.25
# 4581     $8.75
# 4583     $8.75
# 4586    $11.25
# 4587    $11.25
# 4589    $11.25
# 4590    $11.25
# 4591     $8.75
# 4595     $8.75
# 4599     $8.75
# 4604     $8.75
# 4615     $8.75
# ...

# %%
orders.item_price[0]
# Out:
# '$2.39 '

# %%
#replaycing value of case into float type

# %%
price=orders.item_price.str.replace('$','').astype(float)

# %%
orders.item_price=price
g=orders[orders.item_name.str.contains('Chicken')]

# %%
g.loc[g.item_price.idxmax()]

# %%
#how many products cost more then $10.00?
#what is the price of each item with no duplicates item and having 1 quantity?
#how many times were a veggie sales

# %%
item_price_numeric

# %%
count=0
for  x in item_price_numeric:
    if(x>10.0):
        count+=1
print count

# %%
orders.isnull().sum()

# %%
d

# %%
orders change(x):
    #print type(x)
    x=x.strip().replace('$','')
    return float(x)
change('$2.39')

# %%
orders.dtypes
orders['item_price']=orders.item_price.apply(change)

# %%
orders.isnull

# %%
orders.sort_values('item_name')

# %%
orders.loc[[orders.item_price.idxmax()]]
#orders[orders.item_price=orders.item_price.max()]

# %%
orders[orders.item_name.str.contains('Veggie Salad Bowl',case=False)].shape

# %%
orders[(orders.item_name=='Canned Soda')&(orders.quantity>1)].shape[0]

# %%
orders.head()

# %%
#delete the duplicate the item name
orders_new = orders.drop_duplicates(['item_name'])

# %%
#select only the productes with quentity eqantity equls to 1
orders_one_prod=orders_new[orders_new.quantity==1]

# %%
orders_n=orders_one_prod.loc[:,['item_name','item_price']]

# %%
orders_n.sort_values('item_price')

# %%
import re
import numpy as np 
def check(x):
   #print type(x)
    if isinstance(x,str):
        m=re.sub('[\[\]]','',x)

# %%
price=orders.item_price.str.replace('$','').astype(float)
orders.item_price=price
orders.loc[orders[orders.item_name.str.contains('Chicken')].item_price.idxmax()]
#price=orders.item_price.str.replace('$','').astype(float)
# Out:
# order_id                                                            511
# quantity                                                              4
# item_name                                               Chicken Burrito
# choice_description    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# item_price                                                           35
# Name: 1254, dtype: object

# %%
orders.choice_description.str.replace('[\[\]]','').head(10)
#orders.choice_description.apply(check).head()
#orders.choice_description.dropna().apply(check)
# Out:
# 0                                                  NaN
# 1                                           Clementine
# 2                                                Apple
# 3                                                  NaN
# 4    Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# 5    Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...
# 6                                                  NaN
# 7    Tomatillo Red Chili Salsa, Fajita Vegetables, ...
# 8    Tomatillo Green Chili Salsa, Pinto Beans, Chee...
# 9    Fresh Tomato Salsa, Rice, Black Beans, Pinto B...
# Name: choice_description, dtype: object

# %%
#[\[\]]
#reg exp
#orders.choice_description.str.replace('[\[\]]','').head(10)

# %%
#train

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\train.csv")

# %%
df.head(2)

# %%
df.shape

# %%
df[df.Survived==1].Sex.value_counts()

# %%
df.columns

# %%
df[(df.Fare==0)&(df.Survived==0)].Sex.value_counts()

# %%
df.Survived.value_counts()

# %%
df[(df.Sex=='female')&(df.SibSp==0)].Sex.value_counts()

# %%
df.SibSp

# %%
df.SibSp.value_counts()

# %%
df.sort_values('Fare',ascending=False)[:3]

# %%
import numpy as np
p=342/891.0
np.around(p)

342/891.0

# %%
#np.round()
a=342/891.0
np.round(a,decimals=2)

# %%
df.Sex.value_counts()

# %%
# %matplotlib inline

# %%
df.Sex.value_counts().plot(kind='bar')

# %%
d=df.loc[df[df.Sex=='female'].SibSp[df.SibSp==0].index.tolist()]
d.shape

# %%
df[(df.Fare==0)].Sex[df.Survived==0]

# %%
df[(df.Sex=='female')&(df.SibSp==0)].Sex.value_counts()
df[(df.Sex=='female')&(df.SibSp==0)].Survived.value_counts()

# %%
df.Fare.describe()

# %%
df.Fare.hist(bins=10)

# %%
df.sort_values('Fare',ascending=False)[:5]

# %%
df.dtypes

# %%
df.Sex.value_counts()

# %%
# %matplotlib inline
df.Sex.value_counts()

# %% [markdown]
# df.Age.value_counts()

# %%
df[(df.Fare==0)&(df.Survived==1)&(df.Parch==0)].Sex.value_counts()
#df[df.Fare==0].Survived.value_counts()

# %%
#d[d.Parch==0]
df[df.Parch==0].Survived.value_counts()
#d.Parch.value_counts()

# %%
df[(df.Fare==0)&(df.Sex=='male')&(df.SibSp==0)].Survived.value_counts()
f=df[(df.Fare==0)&(df.Sex=='male')&(df.Survived==0)]
f.loc[f.Age.dropna().index]

# %%
f

# %%
f.Age.dropna()

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()

# %%
#df.Fare.hist(bins=5)
df[df.Fare<100].Fare.agg(['min','max','mean','median'])

# %%
df.shape

# %%
m=df[(df.Fare<100)]
#h=m[(m.Fare==np.max(m.Fare))|(m.Fare==np.min(m.Fare))]

# %%
#d=df[df.Sex=='male'].survived
df[(df.Age<15)&(df.Sex=='male')].Survived.value_counts()

# %%
data=df[(df.Age<21)&(df.Sex=='male')].Survived
df.loc[[302],:]

# %%
df.dtypes

# %%
df.loc[df[(df.Age<15)&(df.Sex=='male')].index,['Name','Survived']]
#df[(df.Age<15)&(df.Sex=='male)].Name

# %%
from    matplotlib import pyplot  as plt 
fig,axs=plt.subplots(1,2)
df[df.Sex=='male'].Survived.value_counts().plot(kind='barh',ax=axs[0],title='Male')
df[df.Sex=='female'].Survived.value_counts().plot(kind='barh',ax=axs[1],title='FeMale')
