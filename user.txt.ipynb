# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\user.txt",sep='|')

# %%
df
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# 5          6   42      M      executive    98101
# 6          7   57      M  administrator    91344
# 7          8   36      M  administrator    05201
# 8          9   29      M        student    01002
# 9         10   53      M         lawyer    90703
# 10        11   39      F          other    30329
# 11        12   28      F          other    06405
# 12        13   47      M       educator    29206
# 13        14   45      M      scientist    55106
# 14        15   49      F       educator    97301
# 15        16   21      M  entertainment    10309
# 16        17   30      M     programmer    06355
# 17        18   35      F          other    37212
# ...

# %%
df.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
df.set_index('user_id',inplace=True)

# %%
df.head()
# Out:
#          age gender  occupation zip_code
# user_id
# 1         24      M  technician    85711
# 2         53      F       other    94043
# 3         23      M      writer    32067
# 4         24      M  technician    43537
# 5         33      F       other    15213

# %%
df.occupation.value_counts()
#df=df.groupby('occupation')
# Out:
# student          196
# other            105
# educator          95
# administrator     79
# engineer          67
# programmer        66
# librarian         51
# writer            45
# executive         32
# scientist         31
# artist            28
# technician        27
# marketing         26
# entertainment     18
# healthcare        16
# retired           14
# salesman          12
# lawyer            12
# none               9
# doctor             7
# homemaker          7
# Name: occupation, dtype: int64

# %%
df[df.occupation=='student'].age.mean()

# %%
df[df.occupation=='other'].age.mean()

# %%
df=df.groupby('occupation')

# %%
df

# %%
for i in df.occupation.unique():
    s[i]=df[df.occupation==1].age.mean()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-3c2420e4bda6> in <module>()
#       1
#       2 for i in df.occupation.unique():
# ----> 3     s[i]=df[df.occupation==1].age.mean()
#
# NameError: name 's' is not defined

# %%
for i in df.occupation.unique():
    print(i,'\t',df[df.occupation==i].age.mean())
# Out:
# technician 	 33.148148148148145
# other 	 34.523809523809526
# writer 	 36.31111111111111
# executive 	 38.71875
# administrator 	 38.74683544303797
# student 	 22.081632653061224
# lawyer 	 36.75
# educator 	 42.01052631578948
# scientist 	 35.54838709677419
# entertainment 	 29.22222222222222
# programmer 	 33.121212121212125
# librarian 	 40.0
# homemaker 	 32.57142857142857
# artist 	 31.392857142857142
# engineer 	 36.38805970149254
# marketing 	 37.61538461538461
# none 	 26.555555555555557
# healthcare 	 41.5625
# retired 	 63.07142857142857
# salesman 	 35.666666666666664
# doctor 	 43.57142857142857

# %%
occupation_list=df.occupation.unique()

# %%
occupation_list

# %%
for i in occupation_list:
    mean_age=df[df.occupation==x].age.mean()
    print('\t,' x, '')

# %%
for i in df.groupby('occupation'):
    print(i[0],i[1].age.mean())

# %%
def male_ratio(x):
    total=df[df.occupation==x].gender.value_counts().sum()
    count_male=df[df.occupation==x].gender[df.gender=='M'].count()
    ratio = (count_male/float(total))*100
    return ratio

# %%
s=pd.Series()

# %%
for i in df.occupation.unique():
    s[i]=male_ratio(i)

# %%
s.sort_values(ascending=False)
# Out:
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# dtype: float64
