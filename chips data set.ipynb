# %%
import pandas as pd
import numpy as np

# %%
orders=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\chips.tsv",delimiter='\t')

# %%
orders.head
# Out:
# <bound method NDFrame.head of       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# 5            3         1                           Chicken Bowl
# 6            3         1                          Side of Chips
# 7            4         1                          Steak Burrito
# 8            4         1                       Steak Soft Tacos
# 9            5         1                          Steak Burrito
# 10           5         1                    Chips and Guacamole
# 11           6         1                   Chicken Crispy Tacos
# 12           6         1                     Chicken Soft Tacos
# ...

# %%
orders.shape
# Out:
# (4622, 5)

# %%
orders.item_name.str.upper().head(10)
# Out:
# 0             CHIPS AND FRESH TOMATO SALSA
# 1                                     IZZE
# 2                         NANTUCKET NECTAR
# 3    CHIPS AND TOMATILLO-GREEN CHILI SALSA
# 4                             CHICKEN BOWL
# 5                             CHICKEN BOWL
# 6                            SIDE OF CHIPS
# 7                            STEAK BURRITO
# 8                         STEAK SOFT TACOS
# 9                            STEAK BURRITO
# Name: item_name, dtype: object

# %%
orders.iloc[:5,[0,1,2,4]]
# Out:
#    order_id  quantity                              item_name item_price
# 0         1         1           Chips and Fresh Tomato Salsa     $2.39
# 1         1         1                                   Izze     $3.39
# 2         1         1                       Nantucket Nectar     $3.39
# 3         1         1  Chips and Tomatillo-Green Chili Salsa     $2.39
# 4         2         2                           Chicken Bowl    $16.98

# %%
orders.shape
# Out:
# (4622, 5)

# %%
orders.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
orders['item_price']=orders.item_price.str.replace('$',"").astype('float')

# %%
def change(x):
    x=x.strip().replace('$',"")
    
    return float(x)

# %%
change('$2.39')
# Out:
# 2.39

# %%
orders['item_price']=orders.item_price.apply(change)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-db8b465f106a> in <module>()
# ----> 1 orders['item_price']=orders.item_price.apply(change)
#
# C:\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    2549             else:
#    2550                 values = self.asobject
# -> 2551                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2552
#    2553         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-10-19e7b22f6bb2> in change(x)
#       1 def change(x):
# ----> 2     x=x.strip().replace('$',"")
#       3
#       4     return float(x)
#
# AttributeError: 'float' object has no attribute 'strip'

# %%
orders[orders.item_price>10].shape
# Out:
# (1130, 5)

# %%
orders.dtypes
# Out:
# order_id                int64
# quantity                int64
# item_name              object
# choice_description     object
# item_price            float64
# dtype: object

# %%
orders[orders.item_price>10]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 5            3         1        Chicken Bowl
# 7            4         1       Steak Burrito
# 13           7         1        Chicken Bowl
# 23          12         1     Chicken Burrito
# 39          19         1       Barbacoa Bowl
# 42          20         1        Chicken Bowl
# 43          20         1       Steak Burrito
# 45          21         1     Chicken Burrito
# 52          24         1     Chicken Burrito
# 57          26         1      Veggie Burrito
# 58          27         1       Barbacoa Bowl
# 62          28         1         Veggie Bowl
# 68          30         1     Chicken Burrito
# 79          35         1  Chicken Soft Tacos
# 90          40         1          Steak Bowl
# 91          40         1          Steak Bowl
# 93          41         1    Carnitas Burrito
# 97          43         1       Carnitas Bowl
# 123         54         1        Chicken Bowl
# ...

# %%
#orders.loc[[orders.item_price.idxmax()]]
orders[orders.item_price==orders.item_price.max()]
#orders.item_price.argmax()
# Out:
#       order_id  quantity                     item_name choice_description  \
# 3598      1443        15  Chips and Fresh Tomato Salsa                NaN
#
#       item_price
# 3598       44.25

# %%
#orders[orders.item_name.str.contains('Veggie Salad Bowl',case=False)].shape
orders[orders.item_name.str.contains('Veggie Salad Bowl',case=False)]
# Out:
#       order_id  quantity          item_name  \
# 186         83         1  Veggie Salad Bowl
# 295        128         1  Veggie Salad Bowl
# 455        195         1  Veggie Salad Bowl
# 496        207         1  Veggie Salad Bowl
# 960        394         1  Veggie Salad Bowl
# 1316       536         1  Veggie Salad Bowl
# 1884       760         1  Veggie Salad Bowl
# 2156       869         1  Veggie Salad Bowl
# 2223       896         1  Veggie Salad Bowl
# 2269       913         1  Veggie Salad Bowl
# 2683      1066         1  Veggie Salad Bowl
# 3223      1289         1  Veggie Salad Bowl
# 3293      1321         1  Veggie Salad Bowl
# 4109      1646         1  Veggie Salad Bowl
# 4201      1677         1  Veggie Salad Bowl
# 4261      1700         1  Veggie Salad Bowl
# 4541      1805         1  Veggie Salad Bowl
# 4573      1818         1  Veggie Salad Bowl
#
#                                      choice_description  item_price
# ...

# %%
orders[(orders.item_name=='Canned Soda')&(orders.quantity>1)].shape[0]
orders.head()
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price
# 0                                                NaN        2.39
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98

# %%
orders[(orders.item_name=='Canned Soda') & (orders.quantity>1)].shape
# Out:
# (20, 5)

# %%
orders.choice_description
# Out:
# 0                                                     NaN
# 1                                            [Clementine]
# 2                                                 [Apple]
# 3                                                     NaN
# 4       [Tomatillo-Red Chili Salsa (Hot), [Black Beans...
# 5       [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...
# 6                                                     NaN
# 7       [Tomatillo Red Chili Salsa, [Fajita Vegetables...
# 8       [Tomatillo Green Chili Salsa, [Pinto Beans, Ch...
# 9       [Fresh Tomato Salsa, [Rice, Black Beans, Pinto...
# 10                                                    NaN
# 11      [Roasted Chili Corn Salsa, [Fajita Vegetables,...
# 12      [Roasted Chili Corn Salsa, [Rice, Black Beans,...
# 13      [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...
# 14                                                    NaN
# 15                                                    NaN
# ...

# %%
orders['choice_description']= choice_description.str.replace('[','')
orders['choice_description']= choice_description.str.replace(']','')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-426bfbbd908b> in <module>()
# ----> 1 orders['choice_description']= choice_description.str.replace('[','')
#       2 orders['choice_description']= choice_description.str.replace(']','')
#
# NameError: name 'choice_description' is not defined

# %%
#orders.choice_description.str.replace('[\[\]]','')
# Out:
# 0                                                     NaN
# 1                                              Clementine
# 2                                                   Apple
# 3                                                     NaN
# 4       Tomatillo-Red Chili Salsa (Hot), Black Beans, ...
# 5       Fresh Tomato Salsa (Mild), Rice, Cheese, Sour ...
# 6                                                     NaN
# 7       Tomatillo Red Chili Salsa, Fajita Vegetables, ...
# 8       Tomatillo Green Chili Salsa, Pinto Beans, Chee...
# 9       Fresh Tomato Salsa, Rice, Black Beans, Pinto B...
# 10                                                    NaN
# 11      Roasted Chili Corn Salsa, Fajita Vegetables, R...
# 12      Roasted Chili Corn Salsa, Rice, Black Beans, C...
# 13      Fresh Tomato Salsa, Fajita Vegetables, Rice, C...
# 14                                                    NaN
# 15                                                    NaN
# ...
