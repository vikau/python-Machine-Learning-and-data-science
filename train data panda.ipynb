# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\hp\\Desktop\\dataset\\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
df.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[df.Fare==0].shape
# Out:
# (15, 12)

# %%
df[df.Survived==1].Sex.value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df[(df.Survived==1)&(df.Fare==0)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 271      0      0   LINE   0.0   NaN        S

# %%
df[df.Fare==0].Sex.value_counts()
# Out:
# male    15
# Name: Sex, dtype: int64

# %%
df.loc[df.sort_values('Fare',ascending=False)[:5].index,['Name','Fare']]
# Out:
#                                    Name      Fare
# 258                    Ward, Miss. Anna  512.3292
# 737              Lesurer, Mr. Gustave J  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 88           Fortune, Miss. Mabel Helen  263.0000
# 27       Fortune, Mr. Charles Alexander  263.0000

# %%
#df.Fare.sort_values

# %%
df[df.Fare==0]
df[(df.Survived==1)&(df.Fare==0)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked
# 271      0      0   LINE   0.0   NaN        S

# %%
df.sort_values('Fare',ascending=False)[:5].index
df.loc[[4,5,6]]
# Out:
#    PassengerId  Survived  Pclass                      Name   Sex   Age  SibSp  \
# 4            5         0       3  Allen, Mr. William Henry  male  35.0      0
# 5            6         0       3          Moran, Mr. James  male   NaN      0
# 6            7         0       1   McCarthy, Mr. Timothy J  male  54.0      0
#
#    Parch  Ticket     Fare Cabin Embarked
# 4      0  373450   8.0500   NaN        S
# 5      0  330877   8.4583   NaN        Q
# 6      0   17463  51.8625   E46        S

# %%
m=df.sort_values('Fare',ascending=False)[:5].index
df.loc[m,['Name','Fare']]
# Out:
#                                    Name      Fare
# 258                    Ward, Miss. Anna  512.3292
# 737              Lesurer, Mr. Gustave J  512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  512.3292
# 88           Fortune, Miss. Mabel Helen  263.0000
# 27       Fortune, Mr. Charles Alexander  263.0000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.Fare.hist(bins=40)
plt.show()

# %%
df.Fare.hist(bins=80)

# %%
df.Fare.plot(kind='bar')

# %%
df.Age.hist(bins=20)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df[df.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
df.Age.dropna()
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
# 6      54.0
# 7       2.0
# 8      27.0
# 9      14.0
# 10      4.0
# 11     58.0
# 12     20.0
# 13     39.0
# 14     14.0
# 15     55.0
# 16      2.0
# 18     31.0
# 20     35.0
# 21     34.0
# 22     15.0
# 23     28.0
# 24      8.0
# 25     38.0
# 27     19.0
# 30     40.0
# 33     66.0
# 34     28.0
# 35     42.0
# 37     21.0
# 38     18.0
#        ...
# 856    45.0
# 857    51.0
# 858    24.0
# 860    41.0
# 861    21.0
# 862    48.0
# 864    24.0
# 865    42.0
# 866    27.0
# 867    31.0
# 869     4.0
# 870    26.0
# 871    47.0
# 872    33.0
# 873    47.0
# 874    28.0
# 875    15.0
# 876    20.0
# 877    19.0
# 879    56.0
# 880    25.0
# 881    33.0
# 882    22.0
# 883    28.0
# 884    25.0
# 885    39.0
# 886    27.0
# 887    19.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 714, dtype: float64

# %%
df.Age=df.Age.dropna()

# %%
df.shape
# Out:
# (891, 12)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#df.dropna(inplace=True)

# %%
#df.isnull().sum()

# %%
#df.dropna(inplace=True,how='all')

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.dropna(how='all')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df.Age.agg(['mean','median'])
# Out:
# mean      29.699118
# median    28.000000
# Name: Age, dtype: float64

# %%
df.fillna({'Age':df.Age.median(),
          'Embarked':'s',},inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
df[df.Fare<100].Fare.agg(['min','max','mean','median','std','var'])
# Out:
# min         0.000000
# max        93.500000
# mean       22.411942
# median     13.000000
# std        20.827218
# var       433.772989
# Name: Fare, dtype: float64

# %%
#df.Fare.hist(bins=5)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
# ...

# %%
df.select_dtypes(include=['object']).describe()
# Out:
#                             Name   Sex  Ticket Cabin Embarked
# count                        891   891     891   204      891
# unique                       891     2     681   147        4
# top     Mannion, Miss. Margareth  male  347082    G6        S
# freq                           1   577       7     4      644

# %%
#df.select_dtypes(include=['object'])

# %%
df[df.Fare<100].Fare.max()
# Out:
# 93.5

# %%
df[df.Fare<100]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
#df.Embarked.mode()

# %%
import numpy as np

# %%
df.Fare.apply(np.around,decimals=2)
# Out:
# 0        7.25
# 1       71.28
# 2        7.92
# 3       53.10
# 4        8.05
# 5        8.46
# 6       51.86
# 7       21.08
# 8       11.13
# 9       30.07
# 10      16.70
# 11      26.55
# 12       8.05
# 13      31.28
# 14       7.85
# 15      16.00
# 16      29.12
# 17      13.00
# 18      18.00
# 19       7.22
# 20      26.00
# 21      13.00
# 22       8.03
# 23      35.50
# 24      21.08
# 25      31.39
# 26       7.22
# 27     263.00
# 28       7.88
# 29       7.90
#         ...
# 861     11.50
# 862     25.93
# 863     69.55
# 864     13.00
# 865     13.00
# 866     13.86
# 867     50.50
# 868      9.50
# 869     11.13
# 870      7.90
# 871     52.55
# 872      5.00
# 873      9.00
# 874     24.00
# 875      7.22
# 876      9.85
# 877      7.90
# 878      7.90
# 879     83.16
# 880     26.00
# 881      7.90
# 882     10.52
# 883     10.50
# 884      7.05
# 885     29.12
# 886     13.00
# 887     30.00
# 888     23.45
# 889     30.00
# 890      7.75
# ...

# %%
df.Fare=df.Fare.apply(np.around,decimals=2)

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male  28.0      0
# ...
